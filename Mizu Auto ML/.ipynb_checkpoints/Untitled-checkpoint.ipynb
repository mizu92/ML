# %% [markdown]
# ## Initial Import

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# ## Delete ID and single distinct data

# %%
print(len(data.columns))
for cols in data.columns:
    if (data[cols].nunique() == len(data)) | (data[cols].nunique()==1):
        data.drop(columns=cols, inplace=True)
    else:
        None

print(len(data.columns))
# Out:
# 81
# 80

# %% [markdown]
# ## Drop Nulls and split x and y

# %%
data = data.dropna(axis=1, thresh=int(np.ceil(0.2*len(data))))
y = data['SalePrice']
x = data.drop(['SalePrice'], axis=1)

# %% [markdown]
# ## Split Numerical and Categorical + Imputation

# %%
def get_num_ob(x):
    x_num = x.select_dtypes(exclude='object')
    x_ob = x.select_dtypes(include='object')
    return x_num, x_ob

# %%
def imput_fit_transform(x):
    imput = SimpleImputer(strategy='median')
    x_numeric_imp = pd.DataFrame(imput.fit_transform(x), columns = x.columns, index = x.index)
    return imput, x_numeric_imp

def imput_transform(x, imput):
    x_numeric_imp = pd.DataFrame(imput.transform(x), columns = x.columns, index = x.index)
    return x_numeric_imp

# %%
x_train_num, x_train_obj = get_num_ob(x_train)
imputer, x_train_num_imp = imput_fit_transform(x_train_num)

# %%
x_train_obj.apply(le.fit_transform)
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 254          3       1         3            3          0          4
# 1066         3       1         0            3          0          4
# 638          3       1         3            3          0          4
# 799          3       1         3            3          0          0
# 380          3       1         3            3          0          4
# ...        ...     ...       ...          ...        ...        ...
# 1095         3       1         0            3          0          4
# 1130         3       1         3            3          0          4
# 1294         3       1         3            3          0          4
# 860          3       1         3            3          0          0
# 1126         3       1         3            3          0          4
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  KitchenQual  \
# 254           0            12           2           2  ...            3
# 1066          0             8           2           2  ...            3
# 638           0             7           1           2  ...            3
# 799           0            18           1           2  ...            2
# 380           0            18           2           2  ...            2
# ...         ...           ...         ...         ...  ...          ...
# 1095          0             5           2           2  ...            2
# 1130          0            18           2           2  ...            2
# 1294          0             7           2           2  ...            3
# 860           0             6           2           2  ...            2
# 1126          0             0           2           2  ...            2
#
#       Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 254            6            5           1             1           4
# 1066           6            4           1             1           4
# 638            6            5           6             3           5
# 799            6            4           5             2           4
# 380            6            2           5             2           4
# ...          ...          ...         ...           ...         ...
# 1095           6            2           1             1           4
# 1130           3            4           5             2           4
# 1294           6            5           5             2           4
# 860            6            2           5             2           4
# 1126           6            4           1             0           4
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 254            4           2         8              4
# 1066           4           2         8              4
# 638            5           1         8              4
# 799            4           2         8              4
# 380            4           2         8              4
# ...          ...         ...       ...            ...
# 1095           4           2         8              4
# 1130           4           2         8              4
# 1294           4           0         8              4
# 860            4           2         8              4
# 1126           4           2         8              4
#
# [1168 rows x 39 columns]

# %%
from collections import defaultdict
d = defaultdict(LabelEncoder)

x_train_obj.fillna('Unknown', inplace=True)
## get_dummies
x_train_obj_dummy = pd.get_dummies(x_train_obj)

## get labeled
def le_fit_transform(df):
    le = LabelEncoder()
    fit = df.apply(lambda x: d[x.name].fit_transform(x))
    return fit, d
def le_transform(df, le):
    x_transformed = df.apply(lambda x: d[x.name].transform(x))
    return x_transformed

x_train_obj_le, le = le_fit_transform(x_train_obj)
# Out:
# C:\Users\sintyadi.thong\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %% [markdown]
# ## Feature Scaling

# %%
x_train_concat_lin = pd.concat([x_train_num_imp, x_train_obj_dummy], axis=1)
x_train_concat = pd.concat([x_train_num_imp, x_train_obj_le], axis=1)

# %%
def scaling_fit_transform(x):
    scaler = StandardScaler()
    x_scaled = pd.DataFrame(scaler.fit_transform(x), columns = x.columns, index = x.index)
    return x_scaled, scaler

def scaling_transform(x, scaler):
    x_scaled = pd.DataFrame(scaler.transform(x), columns = x.columns, index = x.index)
    return x_scaled

# %%
x_train_scaled, scaler = scaling_fit_transform(x_train_concat_lin)

# %%
x_train_scaled
# Out:
#       MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 254    -0.866764    -0.012468 -0.212896    -0.820445     0.372217  -0.455469
# 1066    0.074110    -0.502357 -0.265245    -0.088934     1.268609   0.718609
# 638    -0.631546    -0.146074 -0.177841    -0.820445     1.268609  -1.988293
# 799    -0.161109    -0.457822 -0.324474    -0.820445     1.268609  -1.107734
# 380    -0.161109    -0.903175 -0.529035    -0.820445     0.372217  -1.531707
# ...          ...          ...       ...          ...          ...        ...
# 1095   -0.866764     0.343814 -0.127631    -0.088934    -0.524174   1.142582
# 1130   -0.161109    -0.235145 -0.268313    -1.551955    -2.316957  -1.401254
# 1294   -0.866764    -0.457822 -0.234096    -0.820445     1.268609  -0.520696
# 860    -0.161109    -0.680498 -0.283376     0.642577     2.165000  -1.727387
# 1126    1.485421    -0.769569 -0.651399     0.642577    -0.524174   1.175195
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  SaleType_ConLw  \
# 254      -1.346063   -0.597889    1.037269   -0.285504  ...       -0.058621
# 1066      0.439214   -0.597889   -0.971996   -0.285504  ...       -0.058621
# 638      -1.683818   -0.597889   -0.971996   -0.285504  ...       -0.058621
# 799      -1.683818    0.861522    0.267995   -0.285504  ...       -0.058621
# 380      -1.683818   -0.597889   -0.496920   -0.285504  ...       -0.058621
# ...            ...         ...         ...         ...  ...             ...
# 1095      1.018222   -0.597889   -0.919694   -0.285504  ...       -0.058621
# 1130     -1.683818   -0.597889    0.383495   -0.285504  ...       -0.058621
# 1294      0.246211   -0.597889   -0.608062   -0.285504  ...       -0.058621
# 860       0.632217   -0.597889   -0.971996   -0.285504  ...       -0.058621
# 1126      1.066473    0.154982   -0.971996   -0.285504  ...       -0.058621
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  \
# 254      -0.300948     -0.041416      0.39262              -0.265664
# 1066     -0.300948     -0.041416      0.39262              -0.265664
# 638      -0.300948     -0.041416      0.39262              -0.265664
# 799      -0.300948     -0.041416      0.39262              -0.265664
# 380      -0.300948     -0.041416      0.39262              -0.265664
# ...            ...           ...          ...                    ...
# 1095     -0.300948     -0.041416      0.39262              -0.265664
# 1130     -0.300948     -0.041416      0.39262              -0.265664
# 1294     -0.300948     -0.041416      0.39262              -0.265664
# 860      -0.300948     -0.041416      0.39262              -0.265664
# 1126     -0.300948     -0.041416      0.39262              -0.265664
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# 254               -0.058621             -0.077648             -0.125109
# 1066              -0.058621             -0.077648             -0.125109
# 638               -0.058621             -0.077648             -0.125109
# 799               -0.058621             -0.077648             -0.125109
# 380               -0.058621             -0.077648             -0.125109
# ...                     ...                   ...                   ...
# 1095              -0.058621             -0.077648             -0.125109
# 1130              -0.058621             -0.077648             -0.125109
# 1294              -0.058621             -0.077648             -0.125109
# 860               -0.058621             -0.077648             -0.125109
# 1126              -0.058621             -0.077648             -0.125109
#
#       SaleCondition_Normal  SaleCondition_Partial
# 254                0.46002              -0.302636
# 1066               0.46002              -0.302636
# 638                0.46002              -0.302636
# 799                0.46002              -0.302636
# 380                0.46002              -0.302636
# ...                    ...                    ...
# 1095               0.46002              -0.302636
# 1130               0.46002              -0.302636
# 1294               0.46002              -0.302636
# 860                0.46002              -0.302636
# 1126               0.46002              -0.302636
#
# [1168 rows x 285 columns]

# %% [markdown]
# # Machine Learning

# %%
linreg = LinearRegression()

# %%
store = cross_val_score(linreg, x_train_scaled, y_train, cv=5, scoring= 'neg_root_mean_squared_error', n_jobs=-1)
print(store)
print(np.mean(store))
# Out:
# [-4.39238428e+17 -1.10237187e+17 -7.39485921e+16 -7.43115957e+16
#  -3.60139654e+17]
# -2.1157509150395782e+17

# %%
np.mean(y_train)
# Out:
# 181441.5419520548

# %% [markdown]
# ### Using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dectree = DecisionTreeRegressor(random_state=108)
store = cross_val_score(dectree, x_train_concat, y_train, cv=5, scoring= 'neg_root_mean_squared_error', n_jobs=-1)
print(store)
print(np.mean(store))
# Out:
# [-40859.73516733 -55518.64742966 -45818.22102315 -41399.95329282
#  -34689.59651246]
# -43657.23068508605

# %%
x_train_concat
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 254         20.0         70.0   8400.0          5.0          6.0     1957.0
# 1066        60.0         59.0   7837.0          6.0          7.0     1993.0
# 638         30.0         67.0   8777.0          5.0          7.0     1910.0
# 799         50.0         60.0   7200.0          5.0          7.0     1937.0
# 380         50.0         50.0   5000.0          5.0          6.0     1924.0
# ...          ...          ...      ...          ...          ...        ...
# 1095        20.0         78.0   9317.0          6.0          5.0     2006.0
# 1130        50.0         65.0   7804.0          4.0          3.0     1928.0
# 1294        20.0         60.0   8172.0          5.0          7.0     1955.0
# 860         50.0         55.0   7642.0          7.0          8.0     1918.0
# 1126       120.0         53.0   3684.0          7.0          5.0     2007.0
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  KitchenQual  \
# 254         1957.0         0.0       922.0         0.0  ...            3
# 1066        1994.0         0.0         0.0         0.0  ...            3
# 638         1950.0         0.0         0.0         0.0  ...            3
# 799         1950.0       252.0       569.0         0.0  ...            2
# 380         1950.0         0.0       218.0         0.0  ...            2
# ...            ...         ...         ...         ...  ...          ...
# 1095        2006.0         0.0        24.0         0.0  ...            2
# 1130        1950.0         0.0       622.0         0.0  ...            2
# 1294        1990.0         0.0       167.0         0.0  ...            3
# 860         1998.0         0.0         0.0         0.0  ...            2
# 1126        2007.0       130.0         0.0         0.0  ...            2
#
#       Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  \
# 254            6            5           1             1           4
# 1066           6            4           1             1           4
# 638            6            5           6             3           5
# 799            6            4           5             2           4
# 380            6            2           5             2           4
# ...          ...          ...         ...           ...         ...
# 1095           6            2           1             1           4
# 1130           3            4           5             2           4
# 1294           6            5           5             2           4
# 860            6            2           5             2           4
# 1126           6            4           1             0           4
#
#       GarageCond  PavedDrive  SaleType  SaleCondition
# 254            4           2         8              4
# 1066           4           2         8              4
# 638            5           1         8              4
# 799            4           2         8              4
# 380            4           2         8              4
# ...          ...         ...       ...            ...
# 1095           4           2         8              4
# 1130           4           2         8              4
# 1294           4           0         8              4
# 860            4           2         8              4
# 1126           4           2         8              4
#
# [1168 rows x 75 columns]

# %% [markdown]
# ### Using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state=108)
store = cross_val_score(rfr, x_train_concat, y_train, cv=5, scoring= 'neg_root_mean_squared_error', n_jobs=-1)
print(store)
print(np.mean(store))
# Out:
# [-29237.4615338  -35299.39919958 -36273.31648979 -25663.6697506
#  -25428.33685231]
# -30380.43676521694

# %% [markdown]
# ### Using Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(random_state=108)
store = cross_val_score(gbr, x_train_concat, y_train, cv=5, scoring= 'neg_root_mean_squared_error', n_jobs=-1)
print(store)
print(np.mean(store))
# Out:
# [-33552.69174969 -32634.16335264 -31827.68858311 -24015.81311722
#  -22592.30122588]
# -28924.531605709424
